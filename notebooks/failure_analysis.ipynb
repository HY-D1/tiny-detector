# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: /app

# %% [markdown]
# ## Load predictions

# %%
import pandas as pd

preds_path = PROJECT_ROOT / "reports" / "val_predictions.csv"
preds = pd.read_csv(preds_path)

preds.head()
# Out:
#                                                 text  true_label_id  \
# 0        remove or deface Spectre's comments. I have              0
# 1  "\ni don't have time to read your personally-s...              0
# 2  Friends In High Places \n\nPutting your finger...              0
# 3                 LOL \n\nyou made me laugh, thanks.              0
# 4  maybe I should also bring up where you will ta...              0
#
#   true_label_name  pred_label_id pred_label_name  prob_safe  prob_toxic  \
# 0            safe              0            safe   0.994821    0.004096
# 1            safe              0            safe   0.995348    0.003548
# 2            safe              0            safe   0.628034    0.344412
# 3            safe              0            safe   0.972933    0.022957
# 4            safe              0            safe   0.994957    0.003988
#
#    prob_hate
# 0   0.001084
# 1   0.001104
# 2   0.027554
# 3   0.004111
# 4   0.001056

# %%
print("Rows:", len(preds))
print("\nTrue label distribution:")
print(preds["true_label_name"].value_counts())

print("\nPredicted label distribution:")
print(preds["pred_label_name"].value_counts())

overall_acc = (preds["true_label_name"] == preds["pred_label_name"]).mean()
print("\nOverall accuracy:", overall_acc)
# Out:
# Rows: 15958
#
# True label distribution:
# true_label_name
# safe     14335
# toxic     1482
# hate       141
# Name: count, dtype: int64
#
# Predicted label distribution:
# pred_label_name
# safe     14782
# toxic     1176
# Name: count, dtype: int64
#
# Overall accuracy: 0.9483017922045369

# %%
(preds["pred_label_name"] == "hate").sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Build false positives / false negatives

# %%
harmful = ["toxic", "hate"]

false_positives = preds[
    (preds["true_label_name"] == "safe") &
    (preds["pred_label_name"].isin(harmful))
]

false_negatives = preds[
    (preds["true_label_name"].isin(harmful)) &
    (preds["pred_label_name"] == "safe")
]

print("False positives:", len(false_positives))
print("False negatives:", len(false_negatives))
# Out:
# False positives: 134
# False negatives: 581

# %%
# View false positives (safe → toxic/hate)
cols = ["text", "true_label_name", "pred_label_name", "prob_safe", "prob_toxic", "prob_hate"]
false_positives.sample(15, random_state=0)[cols]
# Out:
#                                                     text true_label_name  \
# 11271  Firstly I note that you posted a header disput...            safe
# 8214                          my god your all heartless!            safe
# 2910   Wil Wheaton\nWil Wheaton loves star wars you jerk            safe
# 824    Ok, seriously \n\nHow the hell was the Antlion...            safe
# 12239  ": Absence of statement is not statement of ab...            safe
# 4995   You Need to be Banned!\n\nCorvus cornix why do...            safe
# 7660   I think that hating this Album became a stupid...            safe
# 6044   Compromise \n\nHere's the deal: I'll stop vand...            safe
# 5133              Only a fool turns his back on history.            safe
# 13418  To Richard \n\nOh and also, I find some of the...            safe
# 6324   Clean this crap up \n\nWhy are there so many r...            safe
# 14382  You've just proved my point! Now let's stop it...            safe
# 13384  ok \n\ni am NOT trying to piss you off ,but do...            safe
# 6248                       Khurki is a dumb Assk Jeeves?            safe
# 2361   RE: Your comments to 767-249ER \n\nThose messa...            safe
#
#       pred_label_name  prob_safe  prob_toxic  prob_hate
# 11271           toxic   0.245852    0.702524   0.051623
# 8214            toxic   0.128235    0.760427   0.111339
# 2910            toxic   0.039304    0.854005   0.106691
# 824             toxic   0.254168    0.699090   0.046742
# 12239           toxic   0.476611    0.487988   0.035401
# 4995            toxic   0.064958    0.855556   0.079486
# 7660            toxic   0.107599    0.819846   0.072554
# 6044            toxic   0.131916    0.797868   0.070216
# 5133            toxic   0.187266    0.728067   0.084667
# 13418           toxic   0.132920    0.785332   0.081749
# 6324            toxic   0.064082    0.870649   0.065269
# 14382           toxic   0.282482    0.669706   0.047812
# 13384           toxic   0.391900    0.561931   0.046169
# 6248            toxic   0.035580    0.857879   0.106541
# 2361            toxic   0.307635    0.628221   0.064144

# %%
# View false negatives (toxic/hate → safe)
false_negatives.sample(15, random_state=1)[cols]
# Out:
#                                                     text true_label_name  \
# 10788  Yeah, he said he'd never heard of Ferrara, wha...           toxic
# 13431  "\n\n As much as I'd like to see you (and all ...           toxic
# 1523   "\n\nI agree with your opinion. Such an ignora...           toxic
# 11575  . And then we would have to believe that the E...           toxic
# 14776  "\n\nWhat the hell does that mean? Talk Englis...           toxic
# 15858  does morons like you got a place here? If no, ...           toxic
# 10866  , or if this lousy bot that I use to leave ann...           toxic
# 11956  I will continue vandalising until someone bloc...           toxic
# 2587   Wrongful abuse. \n\nHey im probably gonna piss...           toxic
# 14416  They're about to start construction on new lin...           toxic
# 8125   If you'd ever had heroin-coated condoms during...           toxic
# 5644   hey\nchck my reply to you my my talk page. YOU...           toxic
# 1986   Please stop being smug and supply me with a re...           toxic
# 12973  "\n\nSo Jim Burton, child molesting faggot, I ...           toxic
# 7220   Only a NUTCASE liberal could make a statement ...           toxic
#
#       pred_label_name  prob_safe  prob_toxic  prob_hate
# 10788            safe   0.755159    0.218743   0.026098
# 13431            safe   0.937349    0.056807   0.005844
# 1523             safe   0.972814    0.023261   0.003925
# 11575            safe   0.821407    0.163360   0.015233
# 14776            safe   0.984080    0.014105   0.001815
# 15858            safe   0.732885    0.247966   0.019149
# 10866            safe   0.824751    0.162842   0.012408
# 11956            safe   0.987317    0.010992   0.001690
# 2587             safe   0.850424    0.137894   0.011682
# 14416            safe   0.991243    0.006895   0.001862
# 8125             safe   0.986495    0.011516   0.001989
# 5644             safe   0.971875    0.025280   0.002845
# 1986             safe   0.965514    0.031219   0.003267
# 12973            safe   0.861541    0.126410   0.012049
# 7220             safe   0.978750    0.018213   0.003036

# %%
# Focus on TRUE HATE examples

hate_cases = preds[preds["true_label_name"] == "hate"]
print("True hate cases:", len(hate_cases))

hate_missed = hate_cases[hate_cases["pred_label_name"] != "hate"]
print("Hate missed:", len(hate_missed))

hate_missed.sample(min(20, len(hate_missed)), random_state=42)[cols]
# Out:
# True hate cases: 141
# Hate missed: 141
#                                                     text true_label_name  \
# 7845   This is just a perfect example of how Wikipedi...            hate
# 12200  " name was Willie, and he said he was standing...            hate
# 3368   The Israelis are committing massacres in Gaza,...            hate
# 5612   Fuck you niggerkite. y you deleting so much sh...            hate
# 10325  Hi afghani beggar refugee i love to suck the p...            hate
# 15799  Leave our country. \n\nWe don't want you Arabs...            hate
# 9123   Go fuck yourself!!! you fucking delteted it an...            hate
# 12820  CKCKCKCK\nYo i see u tryin 2 change shit wit C...            hate
# 15483                 Bla bla bla....suck it Irishguy =)            hate
# 783    before calling me a bitch on my own talk at le...            hate
# 3065   Jews \n\nJews are fucking bastards. I hope neo...            hate
# 4545   umm what was the delete for? u fuckin nigger m...            hate
# 1964   You are a fucking Nazi... \n\nEverything I wro...            hate
# 12083              Why is wikipedia so unbelievably gay?            hate
# 12795  Fucking niggers thanks for wasting my time her...            hate
# 15849                     resuu u are all niggers \n  lt            hate
# 2925   == DEAR GWERNOL, U USELESS CUNT MOLESTING NIGG...            hate
# 15650                 go fuck yourself you fucking bitch            hate
# 747    In defence of China! \n\nHey Koreans, who the ...            hate
# 13655  Bullzeye is a faggot and comments on things he...            hate
#
#       pred_label_name  prob_safe  prob_toxic  prob_hate
# 7845            toxic   0.034750    0.868919   0.096331
# 12200           toxic   0.397475    0.534791   0.067734
# 3368             safe   0.990188    0.008049   0.001763
# 5612            toxic   0.026494    0.852429   0.121077
# 10325            safe   0.740668    0.229029   0.030303
# 15799            safe   0.982489    0.015003   0.002508
# 9123            toxic   0.030046    0.867485   0.102469
# 12820           toxic   0.056328    0.819441   0.124232
# 15483            safe   0.748369    0.219892   0.031738
# 783             toxic   0.027002    0.842145   0.130853
# 3065            toxic   0.030304    0.857986   0.111710
# 4545            toxic   0.029315    0.861797   0.108888
# 1964            toxic   0.030005    0.858719   0.111277
# 12083            safe   0.918568    0.071141   0.010291
# 12795           toxic   0.026338    0.867066   0.106596
# 15849           toxic   0.045323    0.836429   0.118249
# 2925            toxic   0.030914    0.840148   0.128938
# 15650           toxic   0.025865    0.842676   0.131459
# 747             toxic   0.036904    0.879022   0.084074
# 13655           toxic   0.449713    0.506736   0.043551

# %% [markdown]
# ## Confidence analysis

# %%
# Confidently wrong safe predictions (harmful but predicted safe with high prob_safe)
fn_confident = false_negatives.sort_values("prob_safe", ascending=False).head(20)
fn_confident[cols]
# Out:
#                                                     text true_label_name  \
# 10759  "\n\nCrusades\nHey, S. Schulz, amigo, stop scr...           toxic
# 6169   "\n\nNeither you nor I are experts in the arti...           toxic
# 9312   I refer to people's constantly taking the word...           toxic
# 10819  "\n""Years after Hanson's death, will her biog...           toxic
# 8849   ":::It appears yo are blowing more Sh*&^ out o...           toxic
# 14406  "\n\n==SUSPICIOUS MASS EDITS-IS ANY ADMINISTRA...           toxic
# 11513  Admins have free reign? \n\nPeople keep removi...           toxic
# 2824   Why should I pay any attention to anything you...           toxic
# 14803  "\n\nAs for the arguements that abo should be ...           toxic
# 3967   "  You think just because you are an admin you...           toxic
# 593    @Dp76764  I don't need rules and regulations o...           toxic
# 9789   Buenos dias, {{safesubst:BASEPAGENAME}}, and w...           toxic
# 2037   "\n""as an admin"" you have almost no basic re...           toxic
# 6746   Is it worth it all \n\nIs it worth all this ad...           toxic
# 15392  "\nThat is absolutely false.\nYou posted a ""c...           toxic
# 1451   I won't stop that. Sometimes Germanic equals G...           toxic
# 11528  Look, what's your problem, kid? Have you got s...           toxic
# 12389  "\n\n Adult-child sex & child sexual abuse \n\...           toxic
# 13439  "\n\n re: msg \n\nyou must understand that the...           toxic
# 3027   Freedom of speech\nI notice you removed my fin...           toxic
#
#       pred_label_name  prob_safe  prob_toxic  prob_hate
# 10759            safe   0.995555    0.003301   0.001143
# 6169             safe   0.995407    0.003479   0.001114
# 9312             safe   0.995366    0.003514   0.001120
# 10819            safe   0.995334    0.003542   0.001124
# 8849             safe   0.995322    0.003634   0.001044
# 14406            safe   0.995292    0.003597   0.001111
# 11513            safe   0.995291    0.003600   0.001109
# 2824             safe   0.995290    0.003631   0.001079
# 14803            safe   0.995287    0.003616   0.001097
# 3967             safe   0.995247    0.003752   0.001001
# 593              safe   0.995232    0.003648   0.001120
# 9789             safe   0.995197    0.003656   0.001146
# 2037             safe   0.995196    0.003627   0.001176
# 6746             safe   0.995163    0.003770   0.001067
# 15392            safe   0.995132    0.003750   0.001118
# 1451             safe   0.995120    0.003726   0.001154
# 11528            safe   0.995105    0.003674   0.001221
# 12389            safe   0.995082    0.003854   0.001064
# 13439            safe   0.995065    0.003901   0.001034
# 3027             safe   0.995061    0.003878   0.001061

# %%
# Confidently wrong toxic predictions (safe but predicted toxic with high prob_toxic)
fp_confident = false_positives.sort_values("prob_toxic", ascending=False).head(20)
fp_confident[cols]
# Out:
#                                                     text true_label_name  \
# 14948  Why do not the two of you, the mentally retard...            safe
# 15675  See?  He understands, and doesn't want interfe...            safe
# 3510   "\n\nSciencewatcher, please read the work of t...            safe
# 13634     Damn straight. Get your facts right next time.            safe
# 8552   LOL PENIS! \n\nLOL!\n\nI AM TALKING TO YOU SO ...            safe
# 6324   Clean this crap up \n\nWhy are there so many r...            safe
# 8229   "   \nShare on printPrint Share on emailEmail ...            safe
# 12996  Vandalism?? You call my changing the Apollo ar...            safe
# 10341  Maybe you're right. Barneca is a really mean a...            safe
# 1334   "\n\n Gregalton, You're Still A Douchebag, Sig...            safe
# 3815   my dear winner, you lunatic remarks ab the ser...            safe
# 717    imo. My Own Prison was their grunge era, Human...            safe
# 150    I can  understand you. YOU DEFINITELY did not ...            safe
# 2009   Nacreous cloud article \n\nI'll edit whatever ...            safe
# 10886  ":: Still stuck at work for an hour or so. On ...            safe
# 6248                       Khurki is a dumb Assk Jeeves?            safe
# 912    friends \n\nI and Jxy are two damned friends w...            safe
# 8407   Some ratings from the VCHip \n\n1. The Power: ...            safe
# 4995   You Need to be Banned!\n\nCorvus cornix why do...            safe
# 168    Hi. You seem far more reasonable that the othe...            safe
#
#       pred_label_name  prob_safe  prob_toxic  prob_hate
# 14948           toxic   0.048282    0.879203   0.072515
# 15675           toxic   0.048882    0.873847   0.077271
# 3510            toxic   0.055598    0.873682   0.070720
# 13634           toxic   0.040521    0.873657   0.085823
# 8552            toxic   0.030385    0.871467   0.098149
# 6324            toxic   0.064082    0.870649   0.065269
# 8229            toxic   0.037962    0.867033   0.095005
# 12996           toxic   0.050370    0.865789   0.083840
# 10341           toxic   0.054866    0.865491   0.079643
# 1334            toxic   0.061429    0.864944   0.073627
# 3815            toxic   0.048466    0.862365   0.089169
# 717             toxic   0.068914    0.862243   0.068843
# 150             toxic   0.063279    0.859504   0.077218
# 2009            toxic   0.059962    0.859440   0.080597
# 10886           toxic   0.076700    0.859020   0.064280
# 6248            toxic   0.035580    0.857879   0.106541
# 912             toxic   0.031391    0.855728   0.112881
# 8407            toxic   0.080081    0.855696   0.064223
# 4995            toxic   0.064958    0.855556   0.079486
# 168             toxic   0.086116    0.855176   0.058708

# %% [markdown]
# ## Observed Failure Modes
#
# ### 1) Class imbalance → hate class collapse
# - `hate` is a tiny fraction of the dataset.
# - The current model never predicts `hate` on validation (0 predicted hate), so recall for hate is ~0.
# - Overall accuracy looks high but is misleading for safety applications.
#
# ### 2) Sarcasm / joking insults (false positives)
# - Some playful or sarcastic comments are flagged as toxic.
#
# ### 3) Borderline rude criticism vs harassment
# - Blunt criticism can be classified as toxic depending on phrasing.
#
# ### 4) Subtle or indirect hate (false negatives)
# - Hate that doesn’t use explicit slurs can be missed or downgraded to safe/toxic.
#
# ### 5) Context dependence
# - Some comments are impossible to classify correctly without conversation context.
